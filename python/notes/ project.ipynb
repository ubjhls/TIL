# %%
import datetime
import requests
import pprint
key = 'f3f6bccf37b5643f47db688990cacfbf'
targetDt = '20190713'
api_url =  f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}'
print(api_url)
response = requests.get(api_url).json()

response.get('boxOfficeResult')
print(response.get('boxOfficeResult').get('weeklyBoxOfficeList')[0].get('movieNm'))
print(response.get('boxOfficeResult').get('weeklyBoxOfficeList')[0].get('audiAcc'))
print(response.get('boxOfficeResult').get('weeklyBoxOfficeList')[0].get('movieCd'))
dic={}
for i in range(len(response.get('boxOfficeResult').get('weeklyBoxOfficeList'))):
    
    dic.update({response.get('boxOfficeResult').get('weeklyBoxOfficeList')[i].get('movieNm') : {
        "영화이름" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[i].get('movieNm'),
        "영화코드" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[i].get('movieCd'),
        "누적관객수" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[i].get('audiAcc')
    }
               })
    
pprint.pprint(dic)
# Out:
# http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key=f3f6bccf37b5643f47db688990cacfbf&targetDt=20190713
# 스파이더맨: 파 프롬 홈
# 6685160
# 20196309
# {'극장판 엉덩이 탐정: 화려한 사건 수첩': {'누적관객수': '101245',
#                            '영화이름': '극장판 엉덩이 탐정: 화려한 사건 수첩',
#                            '영화코드': '20191601'},
#  '기방도령': {'누적관객수': '220182', '영화이름': '기방도령', '영화코드': '20185353'},
#  '기생충': {'누적관객수': '9919835', '영화이름': '기생충', '영화코드': '20183782'},
#  '미드소마': {'누적관객수': '45707', '영화이름': '미드소마', '영화코드': '20192151'},
#  '스파이더맨: 파 프롬 홈': {'누적관객수': '6685160',
#                    '영화이름': '스파이더맨: 파 프롬 홈',
#                    '영화코드': '20196309'},
#  '알라딘': {'누적관객수': '10161238', '영화이름': '알라딘', '영화코드': '20183867'},
#  '애나벨 집으로': {'누적관객수': '459037', '영화이름': '애나벨 집으로', '영화코드': '20199951'},
#  '존 윅 3: 파라벨룸': {'누적관객수': '913066', '영화이름': '존 윅 3: 파라벨룸', '영화코드': '20196655'},
#  '진범': {'누적관객수': '106756', '영화이름': '진범', '영화코드': '20185986'},
# ...

# %%
import datetime
 
now = datetime.datetime.now()
print(now)      # 2015-04-19 12:40:00.320686
 
tomorrow = now + datetime.timedelta(days=-1)
print(tomorrow) # 2015-04-20 12:40:00.320686
# Out:
# 2019-07-19 10:23:38.416414
# 2019-07-18 10:23:38.416414

# %%
import datetime
 
now = datetime.datetime.now()
print(now)          # 2015-04-19 12:11:32.669083
 
Date = now.strftime('20190716')
Date.timedelta(weeks=-1)
print(Date)      # 2015-04-19
# Out:
# 2019-07-23 13:54:19.344219
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-c686b0e3d62e> in <module>
#       5
#       6 Date = now.strftime('20190716')
# ----> 7 Date.timedelta(weeks=-1)
#       8 print(Date)      # 2015-04-19
#
# AttributeError: 'str' object has no attribute 'timedelta'

# %%
import datetime
now = datetime.datetime(2019,7,13)
print(now)
print(now.strftime('%Y%m%d'))

now-datetime.timedelta(weeks=1)
rist = []
for i in range(50):
    rist.append((now-datetime.timedelta(weeks=49-i)).strftime('%Y%m%d'))

print(len(rist))
# Out:
# 2019-07-13 00:00:00
# 20190713
# 50

# %%
import datetime
import requests
import pprint

now = datetime.datetime(2019,7,13)

dic={}
for i in range(51):
    targetDt = (now-datetime.timedelta(weeks=50-i)).strftime('%Y%m%d')
    key = 'f3f6bccf37b5643f47db688990cacfbf'
    api_url =  f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchWeeklyBoxOfficeList.json?key={key}&targetDt={targetDt}&weekGb=0'
    response = requests.get(api_url).json()
    for j in range(len(response.get('boxOfficeResult').get('weeklyBoxOfficeList'))):
        dic.update({response.get('boxOfficeResult').get('weeklyBoxOfficeList')[j].get('movieNm') : {
            "영화이름" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[j].get('movieNm'),
            "영화코드" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[j].get('movieCd'),
            "누적관객수" : response.get('boxOfficeResult').get('weeklyBoxOfficeList')[j].get('audiAcc')
        }})
pprint.pprint(dic)
# Out:
# {'0.0MHz': {'누적관객수': '133522', '영화이름': '0.0MHz', '영화코드': '20188144'},
#  '1919 유관순': {'누적관객수': '46858', '영화이름': '1919 유관순', '영화코드': '20197483'},
#  'BIFAN2019 판타스틱 단편 걸작선 1': {'누적관객수': '25000',
#                              '영화이름': 'BIFAN2019 판타스틱 단편 걸작선 1',
#                              '영화코드': '20192591'},
#  'PMC: 더 벙커': {'누적관객수': '1665200', '영화이름': 'PMC: 더 벙커', '영화코드': '20170658'},
#  '가버나움': {'누적관객수': '87787', '영화이름': '가버나움', '영화코드': '20184896'},
#  '거미줄에 걸린 소녀': {'누적관객수': '25172', '영화이름': '거미줄에 걸린 소녀', '영화코드': '20183007'},
#  '걸캅스': {'누적관객수': '1618601', '영화이름': '걸캅스', '영화코드': '20184082'},
#  '고질라: 킹 오브 몬스터': {'누적관객수': '352862',
#                    '영화이름': '고질라: 킹 오브 몬스터',
#                    '영화코드': '20184865'},
#  '곰돌이 푸 다시 만나 행복해': {'누적관객수': '486038',
#                      '영화이름': '곰돌이 푸 다시 만나 행복해',
#                      '영화코드': '20189123'},
#  '공작': {'누적관객수': '4968325', '영화이름': '공작', '영화코드': '20179101'},
# ...

# %%
len(dic.keys())
# Out:
# 189

# %%
# movieCd	문자열	영화의 대표코드를 출력합니다.
# movieNm	문자열	영화명(국문)을 출력합니다.
# movieNmEn	문자열	영화명(영문)을 출력합니다.
# movieNmOg	문자열	영화명(원문)을 출력합니다.
# watchGradeNm	문자열	관람등급 명칭을 출력합니다.
# openDt	문자열	개봉연도를 출력합니다.
# showTm	문자열	상영시간을 출력합니다.
# repGenreNm	문자열	대표 장르명을 출력합니다.
# peopleNm	문자열	감독명을 출력합니다.

# %%
import datetime
import requests
import pprint
now = datetime.datetime(2019,7,13)bb

# %%
import csv
import requests
import pprint
result =[]
f = open('boxoffice.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
count = 1
for line in rdr:
    if count > 1 and count % 2 == 1:
        result.append(line[1])
    count=count+1
f.close() 


dic={}
movieCd = result[3]
key = 'f3f6bccf37b5643f47db688990cacfbf'
api_url =  f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd={movieCd}'
response = requests.get(api_url).json()
pprint.pprint(response)
# Out:
# {'movieInfoResult': {'movieInfo': {'actors': [{'cast': '신비 목소리',
#                                                'castEn': '',
#                                                'peopleNm': '조현정',
#                                                'peopleNmEn': ''},
#                                               {'cast': '하리 목소리',
#                                                'castEn': '',
#                                                'peopleNm': '김영은',
#                                                'peopleNmEn': ''},
#                                               {'cast': '두리 목소리',
#                                                'castEn': '',
#                                                'peopleNm': '김채하',
#                                                'peopleNmEn': ''},
#                                               {'cast': '강림 목소리',
#                                                'castEn': '',
#                                                'peopleNm': '신용우',
# ...

# %%
import csv
import requests
import pprint
result =[]
f = open('boxoffice.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
count = 1
for line in rdr:
    if count > 1 and count % 2 == 1:
        result.append(line[1])
    count=count+1
f.close() 


dic={}
for movieCd in result:
    key = 'f3f6bccf37b5643f47db688990cacfbf'
    api_url =  f'http://www.kobis.or.kr/kobisopenapi/webservice/rest/movie/searchMovieInfo.json?key={key}&movieCd={movieCd}'
    response = requests.get(api_url).json()
    movieInfo = response['movieInfoResult']['movieInfo']
    dic[response.get('movieInfoResult').get('movieInfo').get('movieCd')] ={
     "영화대표코드" : movieInfo.get('movieCd'),
     "영화명(국문)" : movieInfo.get('movieNm'),
     "영화명(영문)" : movieInfo.get('movieNmEn'),
     "영화명(원문)" : movieInfo.get('movieNmOg'),
     "영화명(관람등급)" : movieInfo.get('audits')[0].get('watchGradeNm') if movieInfo.get('audits') else None,
     "영화명(개봉연도)" : movieInfo.get('openDt'),
     "상영시간" : movieInfo.get('showTm'),
     "장르명" : movieInfo.get('genres')[0].get('genreNm') if movieInfo.get('genres') else None,
     "감독명" : movieInfo.get('directors')[0].get('peopleNm') if movieInfo.get('directors') else None 
    }
print(dic)
# Out:
# {'20181181': {'영화대표코드': '20181181', '영화명(국문)': '미션 임파서블: 폴아웃', '영화명(영문)': 'Mission:Impossible- Fallout', '영화명(원문)': '', '영화명(관람등급)': '15세이상관람가', '영화명(개봉연도)': '20180725', '상영시간': '147', '장르명': '액션', '감독명': '크리스토퍼 맥쿼리'}, '20183361': {'영화대표코드': '20183361', '영화명(국문)': '인크레더블 2', '영화명(영문)': 'INCREDIBLES 2', '영화명(원문)': '', '영화명(관람등급)': '전체관람가', '영화명(개봉연도)': '20180718', '상영시간': '125', '장르명': '애니메이션', '감독명': '브래드 버드'}, '20170942': {'영화대표코드': '20170942', '영화명(국문)': '인랑', '영화명(영문)': 'ILLANG : THE WOLF BRIGADE', '영화명(원문)': '人狼', '영화명(관람등급)': '15세이상관람가', '영화명(개봉연도)': '20180725', '상영시간': '138', '장르명': 'SF', '감독명': '김지운'}, '20185242': {'영화대표코드': '20185242', '영화명(국문)': '신비아파트: 금빛 도깨비와 비밀의 동굴', '영화명(영문)': 'The Haunted House: The Secret of the Cave', '영화명(원문)': '', '영화명(관람등급)': '전체관람가', '영화명(개봉연도)': '20180725', '상영시간': '67', '장르명': '애니메이션', '감독명': '김병갑'}, '20180522': {'영화대표코드': '20180522', '영화명(국문)': '앤트맨과 와스프', '영화명(영문)': 'Ant-Man and the Wasp', '영화명(원문)': '', '영화명(관람등급)': '12세이상관람가', '영화명(개봉연도)': '
# ...

# %%
movieInfo.get('peopleNm')[0] if movieInfo.get('peopleNm') else None

# %%
peopleNm 영화인명
peopleCd	문자열	영화인 코드를 출력합니다.
peopleNm 영화인명
moviePartNm	문자열	참여 분야를 출력합니다.
filmos	문자열	영화인 필모를 나타냅니다.ㅠ

# %%
import csv
import requests
import pprint
result =[]
f = open('movie.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
dic ={}
for peopleCd in result:
    key = 'f3f6bccf37b5643f47db688990cacfbf'
    api_url = f' http://www.kobis.or.kr/kobisopenapi/webservice/rest/people/searchPeopleInfo.json?key={key}&peopleCd={peopleCd}'
    response = requests.get(api_url).json()
    movie_Info = response['movieInfoResult']['movieInfo']
    dic[response.get('movieInfoResult').get('movieInfo').get('peopleNm')] ={
        "영화인코드" : movie_Info.get['peopleCd']
        "영화인명" : movie_Info.get['peopleNm']
        "분야" : movie_Info.get['moviePartNm']
        "필모리스트" : movie_Info.get['filmos']
    }
pprint.pprint(dict)
# Out:
#   File "<ipython-input-216-58ddff2cf776>", line 15
#     "영화인명" : movie_Info.get['peopleNm']
#          ^
# SyntaxError: invalid syntax

# %%
import csv
import requests
import pprint
result =[]
f = open('boxoffice.csv', 'r', encoding='utf-8')
rdr = csv.reader(f)
count = 1
for line in rdr:
    if count > 1 and count % 2 == 1:
        result.append(line[1])
    count=count+1
f.close() 
response = requests.get(api_url).json()
pprint.pprint(respones)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-212-66d0f2819474> in <module>
#      12 f.close()
#      13 response = requests.get(api_url).json()
# ---> 14 pprint.pprint(respones)
#
# NameError: name 'respones' is not defined
